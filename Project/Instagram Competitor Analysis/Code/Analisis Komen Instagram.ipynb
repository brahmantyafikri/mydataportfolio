# %%
# Out:
# Jumlah data: 1641
# Kolom: ['text', 'postUrl', 'replies/0/id', 'replies/0/likesCount', 'replies/0/owner/fbid_v2', 'replies/0/owner/full_name', 'replies/0/owner/has_onboarded_to_text_post_app', 'replies/0/owner/id', 'replies/0/owner/is_mentionable', 'replies/0/owner/is_private', 'replies/0/owner/is_verified', 'replies/0/owner/latest_reel_media', 'replies/0/owner/profile_pic_id', 'replies/0/owner/profile_pic_url', 'replies/0/owner/username', 'replies/0/ownerProfilePicUrl', 'replies/0/ownerUsername', 'replies/0/repliesCount', 'replies/0/text', 'replies/0/timestamp', 'akun', 'replies']
# Kolom komentar digunakan: text
